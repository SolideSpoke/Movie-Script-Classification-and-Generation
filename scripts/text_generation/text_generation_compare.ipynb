# %% [markdown]
# # Text-generation comparison
#
# | **Modèle**                          | **BLEU** | **ROUGE-L** | **BERTScore** | **Perplexité** |
# |------------------------------------|----------|-------------|---------------|----------------|
# | **RNN : GRU (Word2Vec)**                 | 0.0261   | 0.1100      | 0.4550        | —              |
# | **RNN : LSTM (Word2Vec)**                | 0.0215   | 0.1209      | 0.4348        | —              |
# | **RNN : GRU Bidirectionnel (Word2Vec)**  | 0.0249   | 0.1161      | 0.4499        | —              |
# | **RNN : LSTM Bidirectionnel (Word2Vec)** | 0.0254   | 0.1143      | 0.4529        | —              |
# | **FFNN : (Word2Vec)**                | 0.0236   | 0.0943      | 0.7642        | —              |
# | **Transformers : GPT-2 (base)**                   | 0.0115   | 0.0952      | 0.8339        | —              |
# | **Transformers : DistilGPT-2 (yroshan)**                    | 0.0033   | 0.0972      | 0.8279        | —              |
# | **Transformers : GPT-2 (AventIQ)**                | 0.0047   | 0.1063      | 0.8294        | —              |
# | **N-Gram : 3-Gram (len=50)**                | 0.0187   | 0.3115      | 0.3707        | 5905.45        |
# | **N-Gram : 3-Gram (len=100)**               | 0.0225   | 0.3210      | 0.3618        | 5905.45        |
# | **N-Gram : 4-Gram (len=50)**                | 0.0197   | 0.1332      | 0.3740        | 194665.01      |
# | **N-Gram : 4-Gram (len=100)**               | 0.0224   | 0.1329      | 0.3659        | 194665.01      |
